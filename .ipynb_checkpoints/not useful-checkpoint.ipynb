# %%
# pip install huggingface_hub datasets

# %%
# from huggingface_hub import HfApi

# # 1. Masukkan token Anda di sini
# TOKEN = "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"

# # 2. Tentukan nama dataset yang ingin dibuat (format: username/nama-dataset)
# # Ganti 'username-anda' dengan username asli Hugging Face Anda
# repo_id = "jasonchz22/dataset" 

# api = HfApi()

# # 3. Buat repositori dataset baru di Hugging Face (Secara default bersifat Private)
# api.create_repo(
#     repo_id=repo_id,
#     repo_type="dataset",
#     private=False, # Ubah ke False jika ingin dataset Anda bisa dilihat publik
#     token=TOKEN,
#     exist_ok=True # Agar tidak error jika repo sudah pernah dibuat
# )

# # 4. Unggah file berisi dataset Anda
# api.upload_file(
#     path_or_fileobj='./AIML Dataset.csv',  # Jalur ke file CSV Anda
#     path_in_repo='AIML Dataset.csv',       # Nama file saat sudah di dalam Hugging Face
#     repo_id=repo_id,
#     repo_type="dataset",
#     token=TOKEN
# )

# print(print(f"Dataset berhasil diunggah ke: https://huggingface.co{repo_id}"))

# %%
# from datasets import load_dataset

# # 1. Masukkan token Hugging Face (wajib untuk repo Private)
# TOKEN = "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"

# # 2. Tentukan repo ID dataset Anda (format: username/nama-repo)
# repo_id = "jasonchz22/dataset"

# # 3. Load dataset langsung dari Hugging Face Hub
# dataset = load_dataset(repo_id, token=TOKEN)

# print("Dataset berhasil di-load!")
# print(dataset)
