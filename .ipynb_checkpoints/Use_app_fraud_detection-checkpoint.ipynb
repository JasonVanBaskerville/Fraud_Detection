# %%
# How to use app fraud detection
# 1. semua file di clone
# 2. buka jupyter lab
# 3. buka terminal
# 4. jalankan: 
#        streamlit run app.py
# 5. bukan link yg diberikan
# contoh: 
  # Local URL: http://localhost:8504
  # Network URL: http://192.168.0.8:8504
